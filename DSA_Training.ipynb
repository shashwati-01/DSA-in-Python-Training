# %% [markdown]
# <a href="https://colab.research.google.com/github/shashwati-01/DSA-Training/blob/main/DSA_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 12/05/2026 and 13/05/2026

# %%
#1)find last digit no=123

no = int(input("Enter no: "))
res= no %10
print(res)

#logic: no % 10 → gives the last digit of the number.
# Out:
# Enter no: 0987654567
# 7

# %%
#2)Sum of 2 digit no.

#no=45

#10)45(4
#   40
# - - - -
#    5 %

no=int(input("Enter no: "))
n1=no%10
n2=no//10
res=n1+n2
print(res)

#logic: no % 10 → gets the last digit.
#no // 10 → removes the last digit.
#n1 + n2 → adds both values.
# Out:
# Enter no: 89
# 17

# %%
#3)Sum of 3 digit no.

no=int(input("Enter no: "))
n1=no%10  #3
no=no//10 #12
n2=no%10 #2
no=no//10 #1
n3=no%10 #1

res=n1+n2+n3
print(res)

#logic: % 10 → gets the last digit.
#// 10 → removes the last digit.
#First digit stored in n1, second in n2, third in n3.
# Out:
# Enter no: 456
# 15

# %%
#4)Sum of 5 digit
#code:
no = int(input("Enter 5 digit no: "))

n1 = no % 10
no = no // 10

n2 = no % 10
no = no // 10

n3 = no % 10
no = no // 10

n4 = no % 10
no = no // 10

n5 = no % 10

res = n1 + n2 + n3 + n4 + n5

print("Sum =", res)
# Out:
# Enter 5 digit no: 34567
# Sum = 25

# %%
#5)Reverse of 3 digit

no = int(input("Enter 5 digit no: "))

n1 = no % 10
no = no // 10

n2 = no % 10
no = no // 10

n3 = no % 10
no = no // 10

n4 = no % 10
no = no // 10

n5 = no % 10

rev = n1*10000 + n2*1000 + n3*100 + n4*10 + n5

print("Reverse =", rev)
# Out:
# Enter 5 digit no: 45678
# Reverse = 87654

# %%
# 6) no=123456789
#   n1=n0%10
# n2=?
# res=n1+n2

# accept 9 digit no and find sum if and last digit no=123456789 n1=no%10 n2=? res=n1+n2

no = 123456789

n1 = no % 10      # last digit
n2 = no // 100000000   # first digit

res = n1 + n2

print("First digit =", n2)
print("Last digit =", n1)
print("Sum =", res)
# Out:
# First digit = 1
# Last digit = 9
# Sum = 10

# %%
# 7) Reverse a no.

#code:
no=int(input("Enter no: "))
rev=0
while no>0:
  rem=no%10
  rev=rev*10+rem
  no=no//10

print(rev)

#logic:
#no % 10 → gets the last digit.
#rev * 10 + rem → adds that digit to the reversed number.
#no // 10 → removes the last digit from original number.
#Loop continues until number becomes 0.
# Out:
# Enter no: 4567
# 7654

# %%
# 8)Count the digits (no=no//10 remove last digit)

no = int(input("Enter no: "))
count=0
while no>0:
    no=no//10
    count=count+1
print(count)
# Out:
# Enter no: 45678
# 5

# %%
# 9)Sum of digits
# no=123

#code:
no = int(input("Enter no: "))

sum = 0

while no > 0:
    rem = no % 10
    sum = sum + rem
    no = no // 10

print("Sum of Digits =", sum)
# Out:
# Enter no: 789
# Sum of Digits = 24

# %%
# 10)Factorial of a no.

no = int(input("Enter no: "))

fact=1
while no>0:
  fact=fact*no
  no=no-1

print(fact)
# Out:
# Enter no: 3
# 6

# %%
# 11)check no is Palindrome

#n0=121 ->121

no = int(input("Enter no: "))

temp = no   #backup of no.
rev = 0

while no > 0:
    rem = no % 10
    rev = rev * 10 + rem
    no = no // 10

    # print(rev) # Removed to avoid printing intermediate steps

if temp == rev:
    print("Palindrome Number")
else:
    print("Not Palindrome Number")
# Out:
# Enter no: 34567
# Not Palindrome Number

# %%
# 12) Armstrong no

# 153=1^3 + 5^3 + 3^3
# 1+125+27
# 153

no = int(input("Enter no: "))
sum = 0
save = no

# count logic
count = 0

# Use a temporary variable for counting digits to preserve original 'no'
temp_no_count = no
while temp_no_count > 0:
    temp_no_count = temp_no_count // 10
    count = count + 1

# recalculate sum of powers of digits
no = save # Restore original number

while no > 0:
    rem = no % 10
    sum = sum + (rem ** count)
    no = no // 10

if sum == save:
    print(" Armstrong")
else:
    print("No is not Armstrong")
# Out:
# Enter no: 567
# No is not Armstrong

# %%
# 13) print Armstrong no. from 1 to 10,000

for no in range(1, 10001):

    sum = 0
    save = no
    count = 0

    temp = no

    # Count digits
    while temp > 0:
        temp = temp // 10
        count = count + 1

    temp = no

    # Armstrong logic
    while temp > 0:
        rem = temp % 10
        sum = sum + (rem ** count)
        temp = temp // 10

    if sum == save:
        print(save)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 153
# 370
# 371
# 407
# 1634
# 8208
# 9474

# %% [markdown]
# main function code 14

# %%
def add():
  a = int (input("enter a : "))
  b = int (input("enter b :"))
  res = a+b
  print("addition is " , res)   # function with parameters

if __name__ == "__main__":
  add()
# Out:
# enter a : 6
# enter b :7
# addition is  13

# %%
def add(a , b):  # with parameter
    res = a+b
    print("addition is " , res)
if __name__ == "__main__":
  a = int (input("enter a : "))
  b = int (input("enter b :"))
  add(a , b)
# Out:
# enter a : 7
# enter b :7
# addition is  14

# %%
def add(a , b):  # with parameter and return
    res = a+b
    return res
if __name__ == "__main__":
  a = int (input("enter a : "))
  b = int (input("enter b :"))
  r = add(a , b)
  print("addition is " , r)
# Out:
# enter a : 6
# enter b :9
# addition is  15

# %%
def add(a , b):  # with parameter and return with multiple values
    res1 = a+b
    res2 = a-b
    res3 = a*b
    return res1 , res2 , res3
if __name__ == "__main__":
  a = int (input("enter a : "))
  b = int (input("enter b :"))
  r1 , r2 , r3 = add(a , b)
  print("addition is " , r1)
  print("subtraction is " , r2)
  print("multiplication is " , r3)
# Out:
# enter a : 3
# enter b :6
# addition is  9
# subtraction is  -3
# multiplication is  18

# %%
def linear_search(n , arr , key):
    for i in range(n):
        if key == arr[i]:
            print("element found at position ", i+1)
            break
    else:
        print("element not found")

if __name__ == "__main__":
    n = int(input("enter size : "))
    arr=[]

    for i in range(n):
        arr.append(int(input()))

    key = int(input("enter no which is to be searched : "))
    linear_search(n , arr , key)
# Out:
# enter size : 5
# 6
# 9
# 4
# 2
# 8
# enter no which is to be searched : 4
# element found at position  3

# %%
def linear_search(n, arr, target):  #LINEAR SEARCH
    flag = False

    for i in range(n):
        if target == arr[i]:
            flag = True
            loc = i
            break

    if flag == True:
        print("Search is successful")
    else:
        print("Search is unsuccessful")


if __name__ == "__main__":
    n = int(input("Enter size: "))
    arr = []

    for i in range(n):
        arr.append(int(input()))

    target = int(input("Enter target: "))

    linear_search(n, arr, target)
# Out:
# Enter size: 5
# 6
# 9
# 4
# 2
# 8
# Enter target: 4
# Search is successful

# %%
def binary_search(n, arr, target):
    flag = False
    low = 0
    high = n - 1

    while low <= high:
        mid = (low + high) // 2

        if target == arr[mid]:
            flag = True
            loc = mid
            break

        elif target < arr[mid]:
            high = mid - 1

        elif target > arr[mid]:
            low = mid + 1

    if flag == True:
        print("Search is successful and present at ", loc)
    else:
        print("Search is unsuccessful")


if __name__ == "__main__":
    n = int(input("Enter size : "))
    arr = []

    for i in range(n):
        arr.append(int(input()))

    target = int(input("Enter target : "))

    binary_search(n, arr, target)
# Out:
# Enter size : 4
# 6
# 8
# 3
# 2
# Enter target : 3
# Search is unsuccessful

# %%
def bubbleSort(arr):
    n = len(arr)

    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]


if __name__ == '__main__':
    arr = [6, 23, 2, 4, 1, 8, 56, 3]
    bubbleSort(arr)
    print(arr)
# Out:
# [1, 2, 3, 4, 6, 8, 23, 56]

# %%
def bubbleSort(arr):
    n = len(arr)

    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] < arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]


if __name__ == '__main__':
    arr = [6, 23, 2, 4, 1, 8, 56, 3]
    bubbleSort(arr)
    print(arr)
# Out:
# [56, 23, 8, 6, 4, 3, 2, 1]

# %%
def selectionSort(arr):

    for i in range(len(arr)):

        min = arr[i]
        loc = i

        for j in range(i + 1, len(arr)):

            if min > arr[j]:

                min = arr[j]
                loc = j

        arr[i], arr[loc] = arr[loc], arr[i]


if __name__ == '__main__':

    arr = [6, 23, 2, 4, 1, 8, 56, 3]

    selectionSort(arr)
    print(*arr)

    print(arr)
# Out:
# 1 2 3 4 6 8 23 56
# [1, 2, 3, 4, 6, 8, 23, 56]

# %%
def selectionSort(arr):

    for i in range(len(arr)):

        min = arr[i]
        loc = i

        for j in range(i + 1, len(arr)):

            if min < arr[j]:

                min = arr[j]
                loc = j

        arr[i], arr[loc] = arr[loc], arr[i]


if __name__ == '__main__':

    arr = [6, 23, 2, 4, 1, 8, 56, 3]

    selectionSort(arr)
    print(*arr)

    print(arr)
# Out:
# 56 23 8 6 4 3 2 1
# [56, 23, 8, 6, 4, 3, 2, 1]

# %%
def insertion_sort(arr):

    for i in range(1, len(arr)):
        current = arr[i]
        pos = i

        while pos > 0 and current < arr[pos-1]:
            arr[pos] = arr[pos-1]
            pos = pos - 1

        arr[pos] = current

    return arr


arr = [5,2,17,3,4,9,15,1]

print(insertion_sort(arr))
# Out:
# [1, 2, 3, 4, 5, 9, 15, 17]

# %%
class Student:
  def __init__(self):
    print("default constructor")

  def show(self):
    print("I am in show")
    s = Student();
    s.show();

# %% [markdown]
# 15

# %%
import sys

class Stacks:

    def __init__(self):   # fixed
        self.stack = []
        self.top = -1
        self.CAPACITY = 5

    def isFull(self):
        return self.top == self.CAPACITY - 1

    def isEmpty(self):
        return self.top == -1

    def push(self, ele):
        if self.isFull():
            print("Stack is full")
        else:
            self.top += 1
            self.stack.append(ele)
            print(ele, "is pushed")

    def pop(self):
        if self.isEmpty():
            print("Stack is empty")
        else:
            ele = self.stack.pop()
            self.top -= 1
            print(ele, "is popped")

    def peek(self):
        if self.isEmpty():
            print("Stack is empty")
        else:
            print("Top element is:", self.stack[self.top])

    def traverse(self):
        if self.isEmpty():
            print("Stack is empty")
        else:
            print("Stack elements are:")
            for i in range(self.top, -1, -1):
                print(self.stack[i])


if __name__ == "__main__":   # fixed

    obj = Stacks()

    while True:

        print("1. Push")
        print("2. Pop")
        print("3. Peek")
        print("4. Traverse")
        print("0. Exit")

        ch = int(input("Select any choice: "))

        if ch == 1:
            ele = int(input("Enter data: "))
            obj.push(ele)

        elif ch == 2:
            obj.pop()

        elif ch == 3:
            obj.peek()

        elif ch == 4:
            obj.traverse()

        elif ch == 0:
            sys.exit()

        else:
            print("Invalid choice")
# Out:
# 1. Push
# 2. Pop
# 3. Peek
# 4. Traverse
# 0. Exit
# Select any choice: 1
# Enter data: 6
# 6 is pushed
# 1. Push
# 2. Pop
# 3. Peek
# 4. Traverse
# 0. Exit
# Select any choice: 1
# Enter data: 4
# 4 is pushed
# 1. Push
# 2. Pop
# 3. Peek
# 4. Traverse
# 0. Exit
# Select any choice: 1
# Enter data: 8
# 8 is pushed
# 1. Push
# 2. Pop
# 3. Peek
# 4. Traverse
# 0. Exit
# Select any choice: 1
# Enter data: 9
# 9 is pushed
# 1. Push
# 2. Pop
# 3. Peek
# 4. Traverse
# 0. Exit
# Select any choice: 4
# Stack elements are:
# 9
# 8
# 4
# 6
# 1. Push
# 2. Pop
# 3. Peek
# 4. Traverse
# 0. Exit
# Select any choice: 2
# 9 is popped
# 1. Push
# 2. Pop
# 3. Peek
# 4. Traverse
# 0. Exit
# Select any choice: 9
# Invalid choice
# 1. Push
# 2. Pop
# 3. Peek
# 4. Traverse
# 0. Exit
# Select any choice: 4
# Stack elements are:
# 8
# 4
# 6
# 1. Push
# 2. Pop
# 3. Peek
# 4. Traverse
# 0. Exit
# Select any choice: 3
# Top element is: 8
# 1. Push
# 2. Pop
# 3. Peek
# 4. Traverse
# 0. Exit
# ...

# %%
import sys

class Stacks:

    def __init__(self):   # Fixed the constructor name
        self.stack = []
        self.top = -1
        # Note: CAPACITY was removed in this version. If `isFull` functionality is needed, it should be re-added.

    def isEmpty(self):
        return self.top == -1

    def push(self, ele):
        # Without CAPACITY, there's no `isFull` check
        self.top += 1
        self.stack.append(ele)
        print(ele, "is pushed")

    def pop(self):
        if self.isEmpty():
            print("Stack is empty")
        else:
            ele = self.stack.pop()
            self.top -= 1
            print(ele, "is popped")

    def peek(self):
        if self.isEmpty():
            print("Stack is empty")
        else:
            print("Top element is:", self.stack[self.top])

    def traverse(self):
        if self.isEmpty():
            print("Stack is empty")
        else:
            print("Stack elements are:")
            for i in range(self.top, -1, -1):
                print(self.stack[i])


if __name__ == "__main__":

    obj = Stacks()

    while True:

        print("1. Push")
        print("2. Pop")
        print("3. Peek")
        print("4. Traverse")
        print("0. Exit")

        ch = int(input("Select any choice: "))

        if ch == 1:
            ele = int(input("Enter data: "))
            obj.push(ele)

        elif ch == 2:
            obj.pop()

        elif ch == 3:
            obj.peek()

        elif ch == 4:
            obj.traverse()

        elif ch == 0:
            sys.exit()

        else:
            print("Invalid choice")
# Out:
# 1. Push
# 2. Pop
# 3. Peek
# 4. Traverse
# 0. Exit

# %%
import sys

class Stacks:

    def __init__(self):   # fixed
        self.stack = []
        self.top = -1
        self.CAPACITY = 5

    def isFull(self):
        return self.top == self.CAPACITY - 1

    def isEmpty(self):
        return self.top == -1

    def push(self, ele):
        if self.isFull():
            print("Stack is full")
        else:
            self.top += 1
            self.stack.append(ele)
            print(ele, "is pushed")

    def pop(self):
        if self.isEmpty():
            print("Stack is empty")
        else:
            ele = self.stack.pop()
            self.top -= 1
            print(ele, "is popped")
            return ele # Return the popped element for use outside

    def peek(self):
        if self.isEmpty():
            print("Stack is empty")
        else:
            print("Top element is:", self.stack[self.top])

    def traverse(self):
        if self.isEmpty():
            print("Stack is empty")
        else:
            print("Stack elements are:")
            for i in range(self.top, -1, -1):
                print(self.stack[i])


if __name__ == "__main__":   # fixed

    obj = Stacks()

    arr = [10,20,30,40,50]
    rev=[]

    print("Original array : ", arr)

    for i in range(len(arr)):
        obj.push(arr[i])

    rev = []
    while not obj.isEmpty():
        rev.append(obj.pop())

    print("Reversed array : ", rev)
# Out:
# Original array :  [10, 20, 30, 40, 50]
# 10 is pushed
# 20 is pushed
# 30 is pushed
# 40 is pushed
# 50 is pushed
# 50 is popped
# 40 is popped
# 30 is popped
# 20 is popped
# 10 is popped
# Reversed array :  [50, 40, 30, 20, 10]

# %% [markdown]
# 16

# %%
import sys

class Queue:

    def __init__(self):
        self.queue = []
        self.rear = -1
        self.front = 0
        self.CAPACITY = 5

    def isfull(self):
        if self.rear == self.CAPACITY - 1:
            return True
        else:
            return False

    def isEmpty(self):
        if self.rear == -1:
            return True
        else:
            return False

    def insert(self, ele):

        if self.isfull():
            print("Queue is Full")

        else:
            self.rear += 1
            self.queue.append(ele)
            print(ele, "Inserted")

    def delete(self):

        if self.isEmpty():
            print("Queue is Empty")

        else:
            ele = self.queue.pop(0)
            self.rear -= 1
            print(ele, "Deleted")

    def peek(self):

        if self.isEmpty():
            print("Queue is Empty")

        else:
            print("Peek Element =", self.queue[0])

    def traverse(self):

        if self.isEmpty():
            print("Queue is Empty")

        else:
            for i in self.queue:
                print(i, end=" ")
            print()


if __name__ == "__main__":

    obj = Queue()

    while True:

        print("1. insert")
        print("2. delete")
        print("3. Peek")
        print("4. Traverse")
        print("0. Exit")

        ch = int(input("select any choice: "))

        if ch == 1:

            ele = int(input("Enter data: "))
            obj.insert(ele)

        elif ch == 2:

            obj.delete()

        elif ch == 3:

            obj.peek()

        elif ch == 4:

            obj.traverse()

        elif ch == 0:

            sys.exit()

        else:
            print("Invalid Choice")
# Out:
# 1. insert
# 2. delete
# 3. Peek
# 4. Traverse
# 0. Exit
# select any choice: 1
# Enter data: 3
# 3 Inserted
# 1. insert
# 2. delete
# 3. Peek
# 4. Traverse
# 0. Exit
# select any choice: 1
# Enter data: 7
# 7 Inserted
# 1. insert
# 2. delete
# 3. Peek
# 4. Traverse
# 0. Exit
# select any choice: 1
# Enter data: 8
# 8 Inserted
# 1. insert
# 2. delete
# 3. Peek
# 4. Traverse
# 0. Exit
# select any choice: 1
# Enter data: 2
# 2 Inserted
# 1. insert
# 2. delete
# 3. Peek
# 4. Traverse
# 0. Exit
# select any choice: 4
# 3 7 8 2
# 1. insert
# 2. delete
# 3. Peek
# 4. Traverse
# 0. Exit
# select any choice: 3
# Peek Element = 3
# 1. insert
# 2. delete
# 3. Peek
# 4. Traverse
# 0. Exit
# select any choice: 2
# 3 Deleted
# 1. insert
# 2. delete
# 3. Peek
# 4. Traverse
# 0. Exit
# select any choice: 3
# Peek Element = 7
# 1. insert
# 2. delete
# 3. Peek
# 4. Traverse
# 0. Exit
# select any choice: 4
# 7 8 2
# 1. insert
# 2. delete
# 3. Peek
# 4. Traverse
# 0. Exit
# select any choice: 0
# ...

# %%
import sys
class Queue:
    def __init__(self):
        self.queue=[]
        self.rear=-1
        self.front=0
        self.CAPACITY=5

    def isFull(self):
        if self.rear==self.CAPACITY-1:
            return True
        else:
            return False

    def insert(self,ele):
        if self.isFull():
            print("Queue is Full")
        else:
            self.rear+=1   # self.rear = self.rear+1
            self.queue.append(ele)  # self.queue[self.rear]=ele
            print(ele,"Inserted")

    def traverse(self):
        if self.isEmpty():
          print("Queue is empty")
        else:
            print("Queue elements are:")
            for item in self.queue:
              print(item, end=" ")
            print()

    def isEmpty(self):
        if self.rear==-1:
            return True
        else:
            return False

    def delete(self):
        if self.isEmpty():
            print("Queue is Empty")
        else:
            ele=self.queue.pop(0) # Corrected to use pop(0)
            self.rear-=1 # Decrement rear after element is removed
            print(ele, "Deleted")

    def peekFront(self):
        if self.isEmpty():
          print("Queue is empty") # Corrected typo
        else:
          print("Peek Front Element =", self.queue[self.front]) # Corrected syntax and to print value

    def peekRear(self):
        if self.isEmpty():
          print("Queue is empty") # Corrected typo
        else:
          print("Peek Rear Element =", self.queue[self.rear]) # Corrected syntax and to print value



if __name__ == '__main__':
    obj=Queue()
    while True:
        print("1. insert")
        print("2. delete")
        print("3. PeekFront")
        print("4. PeekRear")
        print("5. Traverse")
        print("0. Exit")
        ch=int(input("select any choice: ")) # Added space for clarity
        if ch==1:
            ele=int(input("Enter data: "))
            obj.insert(ele)
        elif ch==2:
            obj.delete()
        elif ch==3:
            obj.peekFront()
        elif ch==4:
            obj.peekRear()
        elif ch==5:
            obj.traverse()
        elif ch==0:
            sys.exit(0)
        else:
            print("Invalid choice")
# Out:
# 1. insert
# 2. delete
# 3. PeekFront
# 4. PeekRear
# 5. Traverse
# 0. Exit
# 4 Inserted
# 1. insert
# 2. delete
# 3. PeekFront
# 4. PeekRear
# 5. Traverse
# 0. Exit
# 8 Inserted
# 1. insert
# 2. delete
# 3. PeekFront
# 4. PeekRear
# 5. Traverse
# 0. Exit
# 6 Inserted
# 1. insert
# 2. delete
# 3. PeekFront
# 4. PeekRear
# 5. Traverse
# 0. Exit
# 7 Inserted
# 1. insert
# 2. delete
# 3. PeekFront
# 4. PeekRear
# 5. Traverse
# 0. Exit
# Peek Front Element = 4
# 1. insert
# 2. delete
# 3. PeekFront
# 4. PeekRear
# 5. Traverse
# 0. Exit
# Queue elements are:
# 4 8 6 7
# 1. insert
# 2. delete
# 3. PeekFront
# 4. PeekRear
# 5. Traverse
# 0. Exit
# Peek Rear Element = 7
# 1. insert
# 2. delete
# 3. PeekFront
# 4. PeekRear
# 5. Traverse
# 0. Exit
# 4 Deleted
# 1. insert
# 2. delete
# 3. PeekFront
# 4. PeekRear
# 5. Traverse
# 0. Exit
# Peek Rear Element = 7
# 1. insert
# 2. delete
# 3. PeekFront
# 4. PeekRear
# 5. Traverse
# 0. Exit
# Queue elements are:
# 8 6 7
# 1. insert
# 2. delete
# ...

# %%
#STACK CODE
import sys

class Stacks:

    def __init__(self):   # fixed
        self.stack = []
        self.top = -1
        self.CAPACITY = 5

    def isFull(self):
        return self.top == self.CAPACITY - 1

    def isEmpty(self):
        return self.top == -1

    def push(self, ele):
        if self.isFull():
            print("Stack is full")
        else:
            self.top += 1
            self.stack.append(ele)
            print(ele, "is pushed")

    def pop(self):
        if self.isEmpty():
            print("Stack is empty")
        else:
            ele = self.stack.pop()
            self.top -= 1
            print(ele, "is popped")

    def peek(self):
        if self.isEmpty():
            print("Stack is empty")
        else:
            print("Top element is:", self.stack[self.top])

    def traverse(self):
        if self.isEmpty():
            print("Stack is empty")
        else:
            print("Stack elements are:")
            for i in range(self.top, -1, -1):
                print(self.stack[i])

#QUEUE CODE

import sys

class Queue:
    def __init__(self):
        self.queue=[]
        self.rear=-1
        self.front=0
        self.CAPACITY=5

    def isFull(self):
        if self.rear==self.CAPACITY-1:
            return True
        else:
            return False

    def insert(self,ele):
        if self.isFull():
            print("Queue is Full")
        else:
            self.rear+=1   # self.rear = self.rear+1
            self.queue.append(ele)  # self.queue[self.rear]=ele
            print(ele,"Inserted")

    def traverse(self):
        if self.isEmpty():
          print("Queue is empty")
        else:
            print("Queue elements are:")
            for item in self.queue:
              print(item, end=" ")
            print()

    def isEmpty(self):
        if self.rear==-1:
            return True
        else:
            return False

    def delete(self):
        if self.isEmpty():
            print("Queue is Empty")
        else:
            ele=self.queue.pop(0) # Corrected to use pop(0)
            self.rear-=1 # Decrement rear after element is removed
            print(ele, "Deleted")

            # insert deleted element into stack
            s.push(ele)

    def peekFront(self):
        if self.isEmpty():
          print("Queue is empty") # Corrected typo
        else:
          print("Peek Front Element =", self.queue[self.front]) # Corrected syntax and to print value

    def peekRear(self):
        if self.isEmpty():
          print("Queue is empty") # Corrected typo
        else:
          print("Peek Rear Element =", self.queue[self.rear]) # Corrected syntax and to print value

          if__name__ == '__main__':
            obj1 =queue()
            obj2 = Stack()
            for i in range(obj1.CAPACITY):
              ele=int(input("enter element"))
              obj1.insert(ele)

              for x in range (10):
                ele = obj1.delete()
                push(ele)

# %%
import sys

# STACK CODE
class Stacks:

    def _init_(self):
        self.stack = []
        self.top = -1
        self.CAPACITY = 5

    def isFull(self):
        return self.top == self.CAPACITY - 1

    def isEmpty(self):
        return self.top == -1

    def push(self, ele):
        if self.isFull():
            print("Stack is Full")
        else:
            self.top += 1
            self.stack.append(ele)
            print(ele, "Pushed into Stack")

    def pop(self):
        if self.isEmpty():
            print("Stack is Empty")
        else:
            ele = self.stack.pop()
            self.top -= 1
            return ele

    def traverse(self):
        if self.isEmpty():
            print("Stack is Empty")
        else:
            print("Stack Elements:")
            for i in range(self.top, -1, -1):
                print(self.stack[i])


# QUEUE CODE
class Queue:

    def _init_(self):
        self.queue = []
        self.front = 0
        self.rear = -1
        self.CAPACITY = 5

    def isFull(self):
        return self.rear == self.CAPACITY - 1

    def isEmpty(self):
        return self.rear == -1

    def insert(self, ele):
        if self.isFull():
            print("Queue is Full")
        else:
            self.rear += 1
            self.queue.append(ele)
            print(ele, "Inserted into Queue")

    def delete(self):
        if self.isEmpty():
            print("Queue is Empty")
        else:
            ele = self.queue.pop(0)
            self.rear -= 1
            return ele

    def traverse(self):
        if self.isEmpty():
            print("Queue is Empty")
        else:
            print("Queue Elements:")
            for item in self.queue:
                print(item, end=" ")
            print()


# main
if _name_ == "_main_":

    obj1 = Queue()
    obj2 = Stacks()

    # ins into queue
    for i in range(obj1.CAPACITY):
        ele = int(input("Enter element: "))
        obj1.insert(ele)

    print("\nOriginal Queue:")
    obj1.traverse()

    # Delete from queue
    for x in range(obj1.CAPACITY):
        ele = obj1.delete()
        obj2.push(ele)

    print("\nStack After Pushing Queue Elements:")
    obj2.traverse()

    # Pop from stack insert into queue
    for x in range(obj2.CAPACITY):
        ele = obj2.pop()
        obj1.insert(ele)

    print("\nReversed Queue:")
    obj1.traverse()

# %%
arr=[1,2,3,4,5,6,7,8]
key=22
loc=3

arr.append(0)
print(arr)

for i in range(len(arr)-1,loc,-1):
    arr[i]=arr[i-1]

arr[loc]=key
print(arr)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 0]
# [1, 2, 3, 22, 4, 5, 6, 7, 8]

# %%
arr=[11,22,33,44,55,66,77]
loc=3

print(arr)

for i in range(loc+1,len(arr)):
    arr[i-1]=arr[i]

arr.pop()

print(arr)
# Out:
# [11, 22, 33, 44, 55, 66, 77]
# [11, 22, 33, 55, 66, 77]

# %%
#array rotation
arr = [1,2,3,4,5]
k=2
for i in range (k):
    last = arr[-1]
    for j in range(len(arr)-1, 0 ,-1):
        arr[j] = arr[j-1]
    arr[0] = last
print(arr)
# Out:
# [4, 5, 1, 2, 3]

# %%
arr = [1,2,3,4,5]
k = 2
for i in range(k):
temp = arr[-1]
for i in range(len(arr)-1 , -1 , -1):
  arr[i] = arr[i-1]
  arr[0] = temp
# Out:
#   File "/tmp/ipykernel_4431/2969480929.py", line 4
#     temp= arr[-1]
#     ^
# IndentationError: expected an indented block after 'for' statement on line 3

# %%
#intersection of two arrays

arr1 = [1, 3, 2, 4]
arr2 = [2, 2]

result = []

for i in arr1:
    if i in arr2 and i not in result:
        result.append(i)

print(result)
# Out:
# [2]

# %%
arr = [-1, 2, -3, 4, 5, -6]

pos = []
neg = []
result = []

for i in arr:
    if i > 0:
        pos.append(i)
    else:
        neg.append(i)



print(result)
# Out:
# [-1, 2, -3, 4, -6, 5]
